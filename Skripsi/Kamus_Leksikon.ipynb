# %% [markdown]
# # Lexicon Based

# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import pytz 
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
pos_lexicon = pd.read_csv('lexicon/InSet-master/positive.tsv',sep='\t')
neg_lexicon = pd.read_csv('lexicon/InSet-master/negative.tsv',sep='\t')

# %%
pos_lexicon
# Out:
#            word  weight
# 0           hai       3
# 1       merekam       2
# 2     ekstensif       3
# 3     paripurna       1
# 4        detail       2
# ...         ...     ...
# 3604  melarikan       3
# 3605    vakansi       3
# 3606    spesial       4
# 3607     asrama       3
# 3608   orisinal       3
#
# [3609 rows x 2 columns]

# %%
neg_lexicon
# Out:
#                       word  weight
# 0       putus tali gantung      -2
# 1                  gelebah      -2
# 2               gobar hati      -2
# 3     tersentuh (perasaan)      -1
# 4                     isak      -5
# ...                    ...     ...
# 6604        kantong kering      -4
# 6605             penggaruk      -3
# 6606               senewen      -4
# 6607            menetapkan      -5
# 6608          kacang botor      -3
#
# [6609 rows x 2 columns]

# %%
lexicon = pos_lexicon.append(neg_lexicon,ignore_index=True)
# Out:
# /var/folders/h4/y51j_l2s31v014vfsgrs3tgm0000gn/T/ipykernel_727/2490020351.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lexicon = pos_lexicon.append(neg_lexicon,ignore_index=True)

# %%
len(lexicon)
# Out:
# 10218

# %%
lexicon.to_csv('insetlexicon.csv')

# %%
lexicon
# Out:
#                  word  weight
# 0                 hai       3
# 1             merekam       2
# 2           ekstensif       3
# 3           paripurna       1
# 4              detail       2
# ...               ...     ...
# 10213  kantong kering      -4
# 10214       penggaruk      -3
# 10215         senewen      -4
# 10216      menetapkan      -5
# 10217    kacang botor      -3
#
# [10218 rows x 2 columns]

# %%
addition = pd.read_csv('lexicon/agusmakmun/sentimentword.csv')

# %%
addition.isnull().sum()
# Out:
# word      0
# weight    0
# dtype: int64

# %%
lexicon_word = lexicon['word'].to_list()

# %%
lexicon['word'][0] in lexicon_word
# Out:
# True

# %%
add_word = []
add_weight = []
for i in range(0,len(addition)):
    if (addition['word'][i] not in lexicon_word):
        add_word.append(addition['word'][i])
        add_weight.append(addition['weight'][i])

addition_lexicon = pd.DataFrame(list(zip(add_word,add_weight)),columns =['word','weight'])

# %%
addition_lexicon
# Out:
#            word  weight
# 0          acuh      -1
# 1        agresi      -3
# 2         ajaib       3
# 3          akal       2
# 4         alarm      -3
# ..          ...     ...
# 821    waktunya      -2
# 822  waspadalah      -2
# 823         wow       3
# 824         wtf      -3
# 825       yatim      -2
#
# [826 rows x 2 columns]

# %%
full_lexicon = lexicon.append(addition_lexicon,ignore_index = True)
# Out:
# /var/folders/h4/y51j_l2s31v014vfsgrs3tgm0000gn/T/ipykernel_3726/3197821956.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_lexicon = lexicon.append(addition_lexicon,ignore_index = True)

# %%
full_lexicon.sample(5)
# Out:
#            word  weight
# 5777      geger      -3
# 6609      harus      -5
# 8654    ginding      -4
# 6872  berak air      -4
# 9160      betul      -4

# %%
full_lexicon[full_lexicon['weight']<0].min()
# Out:
# word      (barang) bekas
# weight                -5
# dtype: object

# %%
my_file = open("lexicon/swearwords/swear-words.txt", "r")
content = my_file.read()
swear_words = content.split("\n")

# %%
weight_swear = [-5 for i in range(len(swear_words))]

# %%
swear_lexicon = pd.DataFrame(list(zip(swear_words,weight_swear)),columns =['word','weight'])

# %%
swear_lexicon
# Out:
#          word  weight
# 0      anjing      -5
# 1     anjiang      -5
# 2       anjir      -5
# 3       anjay      -5
# 4         asu      -5
# ..        ...     ...
# 64  sontoloyo      -5
# 65        tai      -5
# 66      telek      -5
# 67      tolol      -5
# 68                 -5
#
# [69 rows x 2 columns]

# %%
full_lexicon = lexicon.append(swear_lexicon,ignore_index = True)
# Out:
# /var/folders/h4/y51j_l2s31v014vfsgrs3tgm0000gn/T/ipykernel_3726/3862643179.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_lexicon = lexicon.append(swear_lexicon,ignore_index = True)

# %%
len(full_lexicon)
# Out:
# 10287

# %%
full_lexicon
# Out:
#             word  weight
# 0            hai       3
# 1        merekam       2
# 2      ekstensif       3
# 3      paripurna       1
# 4         detail       2
# ...          ...     ...
# 10282  sontoloyo      -5
# 10283        tai      -5
# 10284      telek      -5
# 10285      tolol      -5
# 10286                 -5
#
# [10287 rows x 2 columns]

# %%
def number_of_words(x):
    words = word_tokenize(x['word'])
    number = len(words)
    return number

# %%
full_lexicon['number_of_words'] = full_lexicon.apply(lambda x: number_of_words(x),axis=1)

# %%
full_lexicon = full_lexicon.drop(full_lexicon[full_lexicon['number_of_words'] == 0].index[0],axis=0)

# %%
full_lexicon  = full_lexicon.reset_index(drop=True)

# %%
full_lexicon[full_lexicon['number_of_words'] == 3]
# Out:
#                            word  weight  number_of_words
# 117        jalan bebas hambatan       2                3
# 364              asah asih asuh       2                3
# 574                lunas (kapal       2                3
# 1106       mencium telapak kaki       1                3
# 1501          naik ke pelaminan       3                3
# 1853            naik ke pelamin       3                3
# 1871          cium telapak kaki       1                3
# 1904            minta kpd tuhan       3                3
# 1927         jalan bebas hambat       2                3
# 2073              acuh tak acuh       4                3
# 3609         putus tali gantung      -2                3
# 3678           berlalu dr dunia      -5                3
# 3680  menarik napas penghabisan      -5                3
# 3713       jalan bebas hambatan      -1                3
# 3777           tidak masuk akal      -4                3
# 4452              acuh tak acuh      -3                3
# 5771         jalan bebas hambat      -1                3
# 6025          tarik napas habis      -5                3
# 6089              lalu dr dunia      -5                3
# 6236               lunas (kapal      -3                3
# 6525              asan tak asan      -5                3
# 6917            buang air besar      -5                3
# 8164             ikan kena tuba      -4                3
# 8305      menyerahkan jiwa raga      -4                3
# 8439            buang air kecil      -3                3
# 9788         cacing rambut kuda      -4                3

# %%
full_lexicon.to_csv('lexicon\full_lexicon.csv')

# %%
full_lexicon
# Out:
#             word  weight  number_of_words
# 0            hai       3                1
# 1        merekam       2                1
# 2      ekstensif       3                1
# 3      paripurna       1                1
# 4         detail       2                1
# ...          ...     ...              ...
# 10281      silit      -5                1
# 10282  sontoloyo      -5                1
# 10283        tai      -5                1
# 10284      telek      -5                1
# 10285      tolol      -5                1
#
# [10286 rows x 3 columns]

# %%
modified_lexicon = pd.read_csv('lexicon/modified_full_lexicon.csv')

# %%
modified_lexicon['number_of_words'] = modified_lexicon.apply(lambda x: number_of_words(x),axis=1)

# %%
modified_lexicon.to_csv(r'lexicon\modified_full_lexicon.csv',index=False)

# %% [markdown]
# # Stopwords

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
my_file = open("cleaning_source/combined_stop_words.txt", "r")
content = my_file.read()
stop_words = content.split("\n")

# %%
lexicon_word = modified_lexicon['word'].to_list()

# %%
overlap=[]
for word in stop_words:
    if word in lexicon_word:
        overlap.append(word)
    else:
        kata_dasar = stemmer.stem(word)
        if kata_dasar in lexicon_word:
            overlap.append(word)

# %%
overlap
# Out:
# ['akulah',
#  'amatlah',
#  'andalah',
#  'apa',
#  'artinya',
#  'awalnya',
#  'bagi',
#  'balik',
#  'begini',
#  'beginikah',
#  'bekerja',
#  'benarkah',
#  'berada',
#  'berarti',
#  'berbagai',
#  'beri',
#  'berikut',
#  'berkata',
#  'berkeinginan',
#  'berlainan',
#  'berlangsung',
#  'bermaksud',
#  'bersama',
#  'bersiap',
#  'bertanya',
#  'berturut',
#  'bertutur',
#  'berupa',
#  'betul',
#  'biasa',
#  'boleh',
#  'bolehlah',
#  'bulan',
#  'cukup',
#  'cukuplah',
#  'dahulu',
#  'dari',
#  'datang',
#  'dia',
#  'diberi',
#  'diberikannya',
#  'dibuatnya',
#  'didatangkan',
#  'diingat',
#  'dijelaskan',
#  'dikarenakan',
#  'dikatakannya',
#  'diketahui',
#  'dikira',
#  'dilalui',
#  'dimaksud',
#  'dimaksudkannya',
#  'diminta',
#  'dimulailah',
#  'dimungkinkan',
#  'dipastikan',
#  'diperbuatnya',
#  'diperkirakan',
#  'diperlukan',
#  'dipersoalkan',
#  'dipunyai',
#  'dirinya',
#  'disinilah',
#  'ditanyai',
#  'dituturkannya',
#  'diucapkannya',
#  'entah',
#  'guna',
#  'hanya',
#  'haruslah',
#  'hendak',
#  'hendaknya',
#  'ikut',
#  'ingat-ingat',
#  'itukah',
#  'jadi',
#  'jadinya',
#  'jauh',
#  'jawaban',
#  'jelas',
#  'jelaslah',
#  'kalaulah',
#  'karenanya',
#  'kata',
#  'katakanlah',
#  'kebetulan',
#  'kedua',
#  'kelihatan',
#  'kemungkinan',
#  'kinilah',
#  'kira-kira',
#  'lagi',
#  'lainnya',
#  'lama',
#  'lanjut',
#  'lebih',
#  'mampu',
#  'masalah',
#  'mau',
#  'melainkan',
#  'melalui',
#  'melihatnya',
#  'memastikan',
#  'memberikan',
#  'memerlukan',
#  'meminta',
#  'mempergunakan',
#  'memperlihatkan',
#  'mempunyai',
#  'memungkinkan',
#  'menambahkan',
#  'menanti',
#  'menantikan',
#  'menanyai',
#  'mendapat',
#  'mendatang',
#  'mendatangkan',
#  'mengatakan',
#  'mengenai',
#  'mengetahui',
#  'menghendaki',
#  'mengingatkan',
#  'mengira',
#  'mengucapkannya',
#  'menjadi',
#  'menjelaskan',
#  'menunjukkan',
#  'menurut',
#  'menyampaikan',
#  'menyatakan',
#  'merasa',
#  'meski',
#  'meyakini',
#  'minta',
#  'mulai',
#  'mulanya',
#  'mungkinkah',
#  'naik',
#  'nanti',
#  'pada',
#  'padanya',
#  'pasti',
#  'penting',
#  'perlunya',
#  'pertanyakan',
#  'pihaknya',
#  'punya',
#  'rasanya',
#  'rupanya',
#  'sajalah',
#  'sama',
#  'sampai-sampai',
#  'saya',
#  'sebabnya',
#  'sebagian',
#  'sebaik-baiknya',
#  'sebaliknya',
#  'sebegini',
#  'sebenarnya',
#  'sebesar',
#  'secukupnya',
#  'sedikit',
#  'seharusnya',
#  'seingat',
#  'sejauh',
#  'sekadarnya',
#  'sekali-kali',
#  'sekecil',
#  'sekurangnya',
#  'selama-lamanya',
#  'selanjutnya',
#  'seluruhnya',
#  'semakin',
#  'semampunya',
#  'semata-mata',
#  'sementara',
#  'semua',
#  'semula',
#  'sendirian',
#  'sepantasnya',
#  'seperlunya',
#  'sepertinya',
#  'sering',
#  'serta',
#  'sesudah',
#  'setengah',
#  'setidaknya',
#  'seusai',
#  'siap',
#  'siapakah',
#  'soal',
#  'sudahkah',
#  'supaya',
#  'tambah',
#  'tampak',
#  'tanyakan',
#  'tempat',
#  'tentang',
#  'tentulah',
#  'terasa',
#  'terdahulu',
#  'terdiri',
#  'teringat-ingat',
#  'terjadilah',
#  'terkira',
#  'terlebih',
#  'termasuk',
#  'tersampaikan',
#  'tertuju',
#  'terutama',
#  'tinggi',
#  'tutur',
#  'ucap',
#  'ujar',
#  'umum',
#  'ungkap',
#  'usai',
#  'wah',
#  'walau',
#  'yakin',
#  'yang',
#  'ada',
#  'adanya',
#  'anda',
#  'atas',
#  'baik',
#  'beginilah',
#  'buat',
#  'cuma',
#  'dapat',
#  'dialah',
#  'harus',
#  'hanyalah',
#  'harusnya',
#  'hendaklah',
#  'itu',
#  'itulah',
#  'jangan',
#  'kalau',
#  'karena',
#  'kiranya',
#  'langsung',
#  'lamanya',
#  'makin',
#  'mungkinlah',
#  'nantinya',
#  'paparnya',
#  'pun',
#  'pastilah',
#  'saja',
#  'sampai',
#  'sebab',
#  'sendiri',
#  'seperti',
#  'sebanyak',
#  'sebetulnya',
#  'sedikitnya',
#  'sekali',
#  'selagi',
#  'semuanya',
#  'sendirinya',
#  'sepanjang',
#  'sepantasnyalah',
#  'serupa',
#  'sesama',
#  'sesudahnya',
#  'tetap',
#  'tentu',
#  'tentunya',
#  'tertentu',
#  'tidakkah',
#  'waduh',
#  'nyatanya',
#  'para',
#  'pentingnya',
#  'percuma',
#  'perlukah',
#  'pertanyaan',
#  'pihak',
#  'pukul',
#  'rasa',
#  'rata',
#  'sama-sama',
#  'sampaikan',
#  'satu',
#  'sayalah',
#  'sebagai',
#  'sebaik',
#  'sebaiknya',
#  'sebuah',
#  'segera',
#  'sejenak',
#  'sekadar',
#  'sekalian',
#  'sekurang-kurangnya',
#  'selama',
#  'selamanya',
#  'semampu',
#  'seringnya',
#  'sesegera',
#  'setempat',
#  'setidak-tidaknya',
#  'siapa',
#  'siapapun',
#  'soalnya',
#  'sudah',
#  'sudahlah',
#  'tahu',
#  'tambahnya',
#  'tampaknya',
#  'tanya',
#  'tanyanya',
#  'tengah',
#  'terbanyak',
#  'terdapat',
#  'teringat',
#  'terjadi',
#  'terjadinya',
#  'terlalu',
#  'terlihat',
#  'ternyata',
#  'turut',
#  'tuturnya',
#  'ucapnya',
#  'ujarnya',
#  'umumnya',
#  'ungkapnya',
#  'usah',
#  'dua',
#  'lalu',
#  'lain',
#  'banyak',
#  'besar',
#  'merupakan',
#  'agar',
#  'persen',
#  'diri',
#  'hubungan',
#  'hidup',
#  'mantan',
#  'tinggal',
#  'sesuai',
#  'memberi',
#  'mencari',
#  'ruang',
#  'biasanya',
#  'berdasarkan',
#  'membawa',
#  'tingkat',
#  'dekat',
#  'membantu',
#  'ditemukan',
#  'kegiatan',
#  'tampil',
#  'bertemu',
#  'milik',
#  'menjalani',
#  'upaya',
#  'mengambil',
#  'lewat',
#  'meningkatkan',
#  'kehidupan',
#  'penggunaan',
#  'aku',
#  'kurang',
#  'ya',
#  'amat',
#  'seraya',
#  'tolong']
